# %%
#matthew_berning
#dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# establish relative file paths
hawaii = "Resources/States-of-Interest/Hawaii_District_all.csv"
new_hampshire = "Resources/States-of-Interest/New_Hampshire_District_all.csv"
new_york = "Resources/States-of-Interest/New_York_District_all.csv"
south_carolina = "Resources/States-of-Interest/South_Carolina_District_all.csv"
washington = "Resources/States-of-Interest/Washington_District_all.csv"

# %%
# read csv files
hawaii_df = pd.read_csv(hawaii, encoding = "ANSI")
new_hampshire_df = pd.read_csv(new_hampshire, encoding = "ANSI")
new_york_df = pd.read_csv(new_york, encoding = "ANSI")
south_carolina_df = pd.read_csv(south_carolina, encoding = "ANSI")
washington_df = pd.read_csv(washington, encoding = "ANSI")

# %%
# test read
hawaii_df.head(1)
# Out:
#     Topic      Subject             Title District 01 Estimate District 01 MOE  \
# 0  People  Sex and Age  Total population               714328     (+/- 9864 )
#
#   District 02 Estimate District 02 MOE
# 0               713210     (+/- 9864 )

# %%
# test read
new_hampshire_df.head(1)
# Out:
#     Topic      Subject             Title District 01 Estimate District 01 MOE  \
# 0  People  Sex and Age  Total population               673194     (+/- 6052 )
#
#   District 02 Estimate District 02 MOE
# 0               669601     (+/- 6052 )

# %%
# test read
new_york_df.head(1)
# Out:
#     Topic      Subject             Title District 01 Estimate District 01 MOE  \
# 0  People  Sex and Age  Total population               718652     (+/- 3672 )
#
#   District 02 Estimate District 02 MOE District 03 Estimate District 03 MOE  \
# 0               721373     (+/- 9198 )               725627    (+/- 14277 )
#
#   District 04 Estimate       ...       District 23 Estimate District 23 MOE  \
# 0               728807       ...                     702026     (+/- 3929 )
#
#   District 24 Estimate District 24 MOE District 25 Estimate District 25 MOE  \
# 0               707889     (+/- 3055 )               719033     (+/- 3499 )
#
#   District 26 Estimate District 26 MOE District 27 Estimate District 27 MOE
# 0               714521     (+/- 4881 )               718515     (+/- 6160 )
#
# [1 rows x 57 columns]

# %%
# test read
south_carolina_df.head(1)
# Out:
#     Topic      Subject             Title District 01 Estimate District 01 MOE  \
# 0  People  Sex and Age  Total population               782340     (+/- 7561 )
#
#   District 02 Estimate District 02 MOE District 03 Estimate District 03 MOE  \
# 0               713488    (+/- 10939 )               687378     (+/- 5850 )
#
#   District 04 Estimate District 04 MOE District 05 Estimate District 05 MOE  \
# 0               731886     (+/- 6841 )               718465     (+/- 5329 )
#
#   District 06 Estimate District 06 MOE District 07 Estimate District 07 MOE
# 0               670725    (+/- 14486 )               720087     (+/- 2593 )

# %%
# test read
washington_df.head(1)
# Out:
#     Topic      Subject             Title District 01 Estimate District 01 MOE  \
# 0  People  Sex and Age  Total population               744868    (+/- 12373 )
#
#   District 02 Estimate District 02 MOE District 03 Estimate District 03 MOE  \
# 0               745184    (+/- 11518 )               731931     (+/- 3294 )
#
#   District 04 Estimate       ...       District 06 Estimate District 06 MOE  \
# 0               724053       ...                     713112     (+/- 9396 )
#
#   District 07 Estimate District 07 MOE District 08 Estimate District 08 MOE  \
# 0               768408    (+/- 11025 )               757166    (+/- 11782 )
#
#   District 09 Estimate District 09 MOE District 10 Estimate District 10 MOE
# 0               765319    (+/- 12798 )               738843    (+/- 10720 )
#
# [1 rows x 23 columns]

# %%
#HAWAII
hawaii_df_districts = hawaii_df[["Title", "District 01 Estimate", "District 02 Estimate"]].copy()
hawaii_df_districts = hawaii_df_districts.rename(columns={"Title":"state_dist","District 01 Estimate":"HI_01","District 02 Estimate":"HI_02"})
hawaii_df_districts = hawaii_df_districts.set_index('state_dist')
hawaii_df_districts.drop_duplicates(inplace=True)
# hawaii_df_districts.head()
hawaii_df_transpose = hawaii_df_districts.transpose()
# hawaii_df_transpose.head()
hawaii_df_clean = hawaii_df_transpose[["Total population", "Unemployed", "Unemployment Rate"]]
hawaii_df_clean.head()
# Out:
# state_dist Total population Unemployed Unemployment Rate
# HI_01                714328      11990               3.3
# HI_02                713210      17772               5.2

# %%
#NEW HAMPSHIRE
new_hampshire_df_districts = new_hampshire_df[["Title", "District 01 Estimate", "District 02 Estimate"]].copy()
new_hampshire_df_districts = new_hampshire_df_districts.rename(columns={"Title":"state_dist","District 01 Estimate":"NH_01","District 02 Estimate":"NH_02"})
new_hampshire_df_districts = new_hampshire_df_districts.set_index('state_dist')
new_hampshire_df_districts.drop_duplicates(inplace=True)
# new_hampshire_df_districts.head()
new_hampshire_df_transpose = new_hampshire_df_districts.transpose()
# new_hampshire_df_transpose.head()
new_hampshire_df_clean = new_hampshire_df_transpose[["Total population", "Unemployed", "Unemployment Rate"]]
new_hampshire_df_clean.head()
# Out:
# state_dist Total population Unemployed Unemployment Rate
# NH_01                673194      15157               3.9
# NH_02                669601      13731               3.7

# %%
#NEW YORK
new_york_df_districts = new_york_df[["Title", "District 01 Estimate", "District 02 Estimate","District 03 Estimate","District 04 Estimate","District 05 Estimate","District 06 Estimate","District 07 Estimate","District 08 Estimate","District 09 Estimate","District 10 Estimate","District 11 Estimate","District 12 Estimate","District 13 Estimate","District 14 Estimate","District 15 Estimate","District 16 Estimate","District 17 Estimate","District 18 Estimate","District 19 Estimate","District 20 Estimate","District 21 Estimate","District 22 Estimate","District 23 Estimate","District 24 Estimate","District 25 Estimate","District 26 Estimate","District 27 Estimate"]].copy()
new_york_df_districts = new_york_df_districts.rename(columns={"Title":"state_dist","District 01 Estimate":"NY_01","District 02 Estimate":"NY_02","District 03 Estimate":"NY_03","District 04 Estimate":"NY_04","District 05 Estimate":"NY_05","District 06 Estimate":"NY_06","District 07 Estimate":"NY_07","District 08 Estimate":"NY_08","District 09 Estimate":"NY_09","District 10 Estimate":"NY_10","District 11 Estimate":"NY_11","District 12 Estimate":"NY_12","District 13 Estimate":"NY_13","District 14 Estimate":"NY_14","District 15 Estimate":"NY_15","District 16 Estimate":"NY_16","District 17 Estimate":"NY_17","District 18 Estimate":"NY_18","District 19 Estimate":"NY_19","District 20 Estimate":"NY_20","District 21 Estimate":"NY_21","District 22 Estimate":"NY_22","District 23 Estimate":"NY_23","District 24 Estimate":"NY_24","District 25 Estimate":"NY_25","District 26 Estimate":"NY_26","District 27 Estimate":"NY_27"})
new_york_df_districts = new_york_df_districts.set_index('state_dist')
new_york_df_districts.drop_duplicates(inplace=True)
# new_york_df_districts.head()
new_york_df_transpose = new_york_df_districts.transpose()
# new_york_df_transpose.head()
new_york_df_clean = new_york_df_transpose[["Total population", "Unemployed", "Unemployment Rate"]]
new_york_df_clean.head()
# Out:
# state_dist Total population Unemployed Unemployment Rate
# NY_01                718652      13880               3.7
# NY_02                721373      15344               3.9
# NY_03                725627      12958               3.6
# NY_04                728807      13936               3.6
# NY_05                798555      29025               7.1

# %%
#SOUTH CAROLINA
south_carolina_df_districts = south_carolina_df[["Title", "District 01 Estimate", "District 02 Estimate","District 03 Estimate","District 04 Estimate","District 05 Estimate","District 06 Estimate","District 07 Estimate"]].copy()
south_carolina_df_districts = south_carolina_df_districts.rename(columns={"Title":"state_dist","District 01 Estimate":"SC_01","District 02 Estimate":"SC_02","District 03 Estimate":"SC_03","District 04 Estimate":"SC_04","District 05 Estimate":"SC_05","District 06 Estimate":"SC_06","District 07 Estimate":"SC_07"})
south_carolina_df_districts = south_carolina_df_districts.set_index('state_dist')
south_carolina_df_districts.drop_duplicates(inplace=True)
# south_carolina_df_districts.head()
south_carolina_df_transpose = south_carolina_df_districts.transpose()
# south_carolina_df_transpose.head()
south_carolina_df_clean = south_carolina_df_transpose[["Total population", "Unemployed", "Unemployment Rate"]]
south_carolina_df_clean.head()
# Out:
# state_dist Total population Unemployed Unemployment Rate
# SC_01                782340      15866               4.0
# SC_02                713488      20347               5.8
# SC_03                687378      17171               5.4
# SC_04                731886      16866               4.5
# SC_05                718465      22125               6.5

# %%
#WASHINGTON
washington_df_districts = washington_df[["Title", "District 01 Estimate", "District 02 Estimate","District 03 Estimate","District 04 Estimate","District 05 Estimate","District 06 Estimate","District 07 Estimate","District 08 Estimate","District 09 Estimate","District 10 Estimate"]].copy()
washington_df_districts = washington_df_districts.rename(columns={"Title":"state_dist", "District 01 Estimate":"WA_01","District 02 Estimate":"WA_02","District 03 Estimate":"WA_03","District 04 Estimate":"WA_04","District 05 Estimate":"WA_05","District 06 Estimate":"WA_06","District 07 Estimate":"WA_07","District 08 Estimate":"WA_08","District 09 Estimate":"WA_09","District 10 Estimate":"WA_10"})
washington_df_districts = washington_df_districts.set_index('state_dist')
washington_df_districts.drop_duplicates(inplace=True)
# washington_df_districts.head()
washington_df_transpose = washington_df_districts.transpose()
# washington_df_transpose.head()
washington_df_clean = washington_df_transpose[["Total population", "Unemployed", "Unemployment Rate"]]
washington_df_clean.head(15)
# Out:
# state_dist Total population Unemployed Unemployment Rate
# WA_01                744868      14192               3.6
# WA_02                745184      17529               4.5
# WA_03                731931      22300               6.3
# WA_04                724053      17263               5.2
# WA_05                716859      18614               5.4
# WA_06                713112      16500               5.1
# WA_07                768408      17547               3.8
# WA_08                757166      18378               4.7
# WA_09                765319      21233               4.9
# WA_10                738843      22858               6.4

# %%
all_states_df = pd.concat([hawaii_df_clean, new_hampshire_df_clean, washington_df_clean, south_carolina_df_clean, new_york_df_clean])

all_states_df = all_states_df.rename(columns={"Total population":"district_population", "Unemployed":"unemployed", "Unemployment Rate":"unemployment_rate"})

all_states_df.head()
# Out:
# state_dist district_population unemployed unemployment_rate
# HI_01                   714328      11990               3.3
# HI_02                   713210      17772               5.2
# NH_01                   673194      15157               3.9
# NH_02                   669601      13731               3.7
# WA_01                   744868      14192               3.6

# %%
df = all_states_df.reset_index()
# df.head()
# df2 = df.rename(columns={"state_dist":"id","index":"state_dist"})
# df2.reset_index()
# # df2.index.names = ['id']
# df2.rename_axis('id')
# df2.head()

df2 = df.rename_axis(None)

df3 = df2.rename_axis(None, axis='columns')

df4 = df3.rename(columns={"index":"state_dist"})
df4.head()
# Out:
#   state_dist district_population unemployed unemployment_rate
# 0      HI_01              714328      11990               3.3
# 1      HI_02              713210      17772               5.2
# 2      NH_01              673194      15157               3.9
# 3      NH_02              669601      13731               3.7
# 4      WA_01              744868      14192               3.6

# %%
# Establish Connection to MySQL
engine = create_engine("mysql://root:$M$CK@butt.com@localhost:3306/election_2018_db")
conn = engine.connect()

# %%
engine.table_names()
# Out:
# ['congressional_district_unemployment']

# %%
all_states_df.to_sql(name='congressional_district_unemployment', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     249             exc, value = sys.exc_info()[:2]
# --> 250             self.errorhandler(self, exc, value)
#     251         self._executed = query
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\connections.py in defaulterrorhandler(***failed resolving arguments***)
#      49     if isinstance(errorvalue, BaseException):
# ---> 50         raise errorvalue
#      51     if errorclass is not None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     246         try:
# --> 247             res = self._query(query)
#     248         except Exception:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     411     def _query(self, q):
# --> 412         rowcount = self._do_query(q)
#     413         self._post_get_result()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in _do_query(self, q)
#     374         self._last_executed = q
# --> 375         db.query(q)
#     376         self._do_get_result()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     275         else:
# --> 276             _mysql.connection.query(self, query)
#     277
#
# IntegrityError: (1364, "Field 'state_dist' doesn't have a default value")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-64-62488f2cfbe0> in <module>()
# ----> 1 all_states_df.to_sql(name='congressional_district_unemployment', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2125         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2126                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2127                    dtype=dtype)
#    2128
#    2129     def to_pickle(self, path, compression='infer',
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1147                          schema=schema, dtype=dtype)
#    1148         table.create()
# -> 1149         table.insert(chunksize)
#    1150         if (not name.isdigit() and not name.islower()):
#    1151             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize)
#     661
#     662                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 663                 self._execute_insert(conn, keys, chunk_iter)
#     664
#     665     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     636         """Insert data into this table with database connection"""
#     637         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 638         conn.execute(*self.insert_statement(data, conn))
#     639
#     640     def insert(self, chunksize=None):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1191                         statement,
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#    1195             self._handle_dbapi_exception(
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     505
#     506     def do_execute(self, cursor, statement, parameters, context=None):
# --> 507         cursor.execute(statement, parameters)
#     508
#     509     def do_execute_no_params(self, cursor, statement, context=None):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     248         except Exception:
#     249             exc, value = sys.exc_info()[:2]
# --> 250             self.errorhandler(self, exc, value)
#     251         self._executed = query
#     252         if not self._defer_warnings:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\connections.py in defaulterrorhandler(***failed resolving arguments***)
#      48     del connection
#      49     if isinstance(errorvalue, BaseException):
# ---> 50         raise errorvalue
#      51     if errorclass is not None:
#      52         raise errorclass(errorvalue)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     245         res = None
#     246         try:
# --> 247             res = self._query(query)
#     248         except Exception:
#     249             exc, value = sys.exc_info()[:2]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     410
#     411     def _query(self, q):
# --> 412         rowcount = self._do_query(q)
#     413         self._post_get_result()
#     414         return rowcount
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\cursors.py in _do_query(self, q)
#     373         db = self._get_db()
#     374         self._last_executed = q
# --> 375         db.query(q)
#     376         self._do_get_result()
#     377         return self.rowcount
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     274             self.read_query_result()
#     275         else:
# --> 276             _mysql.connection.query(self, query)
#     277
#     278     def __enter__(self):
#
# IntegrityError: (_mysql_exceptions.IntegrityError) (1364, "Field 'state_dist' doesn't have a default value") [SQL: 'INSERT INTO congressional_district_unemployment (district_population, unemployed, unemployment_rate) VALUES (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s), (%s, %s, %s)'] [parameters: ('714328', '11990', '3.3', '713210', '17772', '5.2', '673194', '15157', '3.9', '669601', '13731', '3.7', '744868', '14192', '3.6', '745184', '17529', '4.5', '731931', '22300', '6.3', '724053', '17263', '5.2', '716859', '18614', '5.4', '713112', '16500', '5.1', '768408', '17547', '3.8', '757166', '18378', '4.7', '765319', '21233', '4.9', '738843', '22858', '6.4', '782340', '15866', '4.0', '713488', '20347', '5.8', '687378', '17171', '5.4', '731886', '16866', '4.5', '718465', '22125', '6.5', '670725', '23210', '7.4', '720087', '24162', '7.4', '718652', '13880', '3.7', '721373', '15344', '3.9', '725627', '12958', '3.6', '728807', '13936', '3.6', '798555', '29025', '7.1', '761797', '14971', '3.8', '755717', '24715', '6.4', '793532', '25717', '6.6', '750170', '28342', '7.3', '733275', '17435', '4.4', '755204', '18247', '5.0', '714279', '15408', '3.3', '802800', '38237', '8.9', '691813', '19705', '5.3', '781143', '46201', '13.4', '742552', '21764', '5.7', '746412', '19618', '5.1', '730114', '16395', '4.4', '700975', '17247', '5.0', '732130', '22407', '5.7', '705669', '16837', '5.1', '696819', '18346', '5.4', '702026', '17422', '5.2', '707889', '20553', '5.8', '719033', '21147', '5.6', '714521', '20274', '5.5', '718515', '13870', '3.8')] (Background on this error at: http://sqlalche.me/e/gkpj)
